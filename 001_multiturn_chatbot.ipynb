# %%
import os
from anthropic import Anthropic
from dotenv import load_dotenv

load_dotenv()

client = Anthropic(api_key=os.environ.get("ANTHROPIC_API_KEY"))

def add_user_message(messages, text):
    user_message={"role":"user", "content":text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message={"role":"assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model="claude-sonnet-4-5-20250929",
        max_tokens=1024,
        messages=messages
    )

    return message.content[0].text

# %%
messages = []

while True:
    user_input = input("> ")
    print("> ", user_input)
    add_user_message(messages, user_input)
    answer = chat(messages)
    add_assistant_message(messages, answer)
    print(answer)
# Out:
# >  How is IU's BS in Marketing program?
# # IU's BS in Marketing Program
#
# IU (Indiana University) has a **strong and well-regarded marketing program** through the Kelley School of Business. Here are the key strengths:
#
# ## Reputation
# - Kelley is consistently ranked among the top undergraduate business schools in the U.S.
# - The marketing department specifically is highly rated nationally
# - Strong alumni network, especially in the Midwest
#
# ## Program Highlights
# - **Experiential learning** - real client projects and case competitions
# - **Specialization options** - digital marketing, brand management, analytics
# - **Integrated curriculum** - combines strategy, analytics, and creative thinking
# - Access to **professional development** and career coaching through Kelley
#
# ## Career Outcomes
# - High placement rates with major companies
# - Strong recruiting presence from Fortune 500 companies
# - Good starting salaries compared to national averages
#
# ## Considerations
# - **Competitive admission** - need to apply to Kelley (either direct admit or standard admission after freshman year)
# - Large program size - requires self-advocacy
# - Bloomington campus offers typical Big 10 college experience
#
# Is there a specific aspect of the program you'd like to know more about (curriculum, admissions, internships, etc.)?
# >  How many credits are there in the program and can I attend a semester online if I have an internship?
# # IU Marketing BS Credits & Online Options
#
# ## Credit Requirements
#
# The **BS in Marketing at Kelley typically requires around 120-124 total credits**, which includes:
# - General education requirements
# - Kelley business core courses
# - Marketing major requirements (usually 15-18 credits)
# - Electives
#
# The exact number can vary slightly based on AP credits, placement tests, and elective choices.
#
# ## Online/Remote Semester Options
#
# This is where it gets **trickier**:
#
# - **Kelley traditionally emphasizes in-person attendance**, especially for upper-level business courses
# - Many core marketing and business classes have participation/teamwork components that require being on campus
# - **However**, options may include:
#   - Taking the internship during **summer** (most common approach)
#   - Doing a **part-time internship** while taking classes
#   - **Study abroad programs** that might include internship components
#   - Potentially arranging a **lighter course load** during internship semester
#
# ## Best Approach
#
# I'd recommend **contacting Kelley's advising office directly** because:
# - Policies may have evolved (especially post-COVID)
# - They might have formal internship semester programs I'm not aware of
# - Individual accommodations might be possible depending on circumstances
#
# Most Kelley students do internships during summers between sophomore-junior or junior-senior years rather than taking a full semester off.
#
# Would you like information about typical internship timing or how to balance coursework with career preparation?
# >  Nope, that's enough information for now thank you
# You're welcome! Good luck with your decision about IU's marketing program. Feel free to come back if you have more questions later!
# >
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[7], line 7
#       3 while True:
#       4     user_input = input("> ")
#       5     print("> ", user_input)
#       6     add_user_message(messages, user_input)
# ----> 7     answer = chat(messages)
#       8     add_assistant_message(messages, answer)
#       9     print(answer)
#
# Cell In[1], line 18, in chat(messages)
#      17 def chat(messages):
# ---> 18     message = client.messages.create(
#      19         model="claude-sonnet-4-5-20250929",
#      20         max_tokens=1024,
#      21         messages=messages
#
# File ~/Claude Course/venv/lib/python3.13/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File ~/Claude Course/venv/lib/python3.13/site-packages/anthropic/resources/messages/messages.py:1050, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, user_profile_id, extra_headers, extra_query, extra_body, timeout)
#    1043     warnings.warn(
#    1044         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1045         UserWarning,
#    1046         stacklevel=3,
#    1047     )
#    1049 extra_headers = {**strip_not_given({"anthropic-user-profile-id": user_profile_id}), **(extra_headers or {})}
# -> 1050 return self._post(
#    1051     "/v1/messages",
#    1052     body=maybe_transform(
#    1053         {
#    1054             "max_tokens": max_tokens,
#    1055             "messages": messages,
#    1056             "model": model,
#    1057             "cache_control": cache_control,
#    1058             "container": container,
#    1059             "inference_geo": inference_geo,
#    1060             "metadata": metadata,
#    1061             "output_config": output_config,
#    1062             "service_tier": service_tier,
#    1063             "stop_sequences": stop_sequences,
#    1064             "stream": stream,
#    1065             "system": system,
#    1066             "temperature": temperature,
#    1067             "thinking": thinking,
#    1068             "tool_choice": tool_choice,
#    1069             "tools": tools,
#    1070             "top_k": top_k,
#    1071             "top_p": top_p,
#    1072         },
#    1073         message_create_params.MessageCreateParamsStreaming
#    1074         if stream
#    1075         else message_create_params.MessageCreateParamsNonStreaming,
#    1076     ),
#    1077     options=make_request_options(
#    1078         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1079     ),
#    1080     cast_to=Message,
#    1081     stream=stream or False,
#    1082     stream_cls=Stream[RawMessageStreamEvent],
#    1083 )
#
# File ~/Claude Course/venv/lib/python3.13/site-packages/anthropic/_base_client.py:1536, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1527     warnings.warn(
#    1528         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1529         "Please pass raw bytes via the `content` parameter instead.",
#    1530         DeprecationWarning,
#    1531         stacklevel=2,
#    1532     )
#    1533 opts = FinalRequestOptions.construct(
#    1534     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535 )
# -> 1536 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Claude Course/venv/lib/python3.13/site-packages/anthropic/_base_client.py:1195, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1192     if not response.is_closed:
#    1193         response.read()
# -> 1195     raise self._make_status_error_from_response(response) from None
#    1197 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.6: user messages must have non-empty content'}, 'request_id': 'req_011CdumkRMAUVRiNy2nz2hJs'}
