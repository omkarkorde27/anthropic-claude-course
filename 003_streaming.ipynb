# %%
import os
from anthropic import Anthropic
from dotenv import load_dotenv

load_dotenv()

client = Anthropic(api_key=os.environ.get("ANTHROPIC_API_KEY"))

def add_user_message(messages, text):
    user_message = {"role":"user", "content":text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role":"assistant", "content":text}
    messages.append(assistant_message)

# %%
messages = []

add_user_message(messages, "Write a 1 sentence description of a fake database.")

stream = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    max_tokens=1024,
    messages=messages,
    stream=True
)

for event in stream:
    print(event)
# Out:
# RawMessageStartEvent(message=Message(id='msg_011CdwejirYUxLAJ1Fs7tQKD', container=None, content=[], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason=None, stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=19, output_tokens=6, output_tokens_details=None, server_tool_use=None, service_tier='standard')), type='message_start')
# RawContentBlockStartEvent(content_block=TextBlock(citations=None, text='', type='text'), index=0, type='content_block_start')
# RawContentBlockDeltaEvent(delta=TextDelta(text='A fake database is a sim', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text='ulated or mock data storage system that contains artificially generated information instead of real user or business data, commonly', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' used for testing, development, or demonstration purposes.', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockStopEvent(index=0, type='content_block_stop')
# RawMessageDeltaEvent(delta=Delta(container=None, stop_details=None, stop_reason='end_turn', stop_sequence=None), type='message_delta', usage=MessageDeltaUsage(cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=19, output_tokens=40, output_tokens_details=None, server_tool_use=None))
# RawMessageStopEvent(type='message_stop')

# %%
messages = []

add_user_message(messages, "Why are the divorce rates in western countries are higher than India?")

with client.messages.stream(
    model="claude-sonnet-4-5-20250929",
    max_tokens=1024,
    messages=messages
) as stream:
    for text in stream.text_stream:
        print(text, end="")
# Out:
# # Key Factors Behind Different Divorce Rates
#
# ## Cultural and Social Factors
#
# **Social stigma in India**
# - Divorce carries significant social shame, particularly for women
# - Can affect marriage prospects for family members
# - Community pressure to maintain marriages
#
# **Family structure**
# - Indian extended families often intervene to prevent divorce
# - Western emphasis on individual happiness vs. Indian focus on family unit preservation
#
# ## Legal and Economic Realities
#
# **Women's economic independence**
# - Higher female workforce participation in West provides financial exit option
# - Many Indian women depend economically on husbands
#
# **Legal accessibility**
# - Divorce processes are more straightforward in most Western countries
# - Indian divorce laws can be complex, lengthy, and expensive
#
# ## Marriage Dynamics
#
# **Arranged vs. choice marriages**
# - Different expectations and frameworks for evaluating marriage success
# - Lower divorce expectations may mean higher tolerance for dissatisfaction
#
# **Social acceptance**
# - Western societies generally normalize divorce as a life option
# - India still largely views marriage as a permanent institution
#
# ## Important Context
#
# Low divorce rates don't necessarily indicate happier marriages - they may reflect:
# - Limited alternatives for unhappy spouses
# - Social and economic pressures to stay
# - Different definitions of an "acceptable" marriage
#
# Recent data shows Indian divorce rates **are rising**, especially in urban areas, suggesting these patterns evolve with social change.
